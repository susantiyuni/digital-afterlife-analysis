# %%
# !pip install pandas nltk bertopic youtube_comment_downloader

# %%
from itertools import islice
from youtube_comment_downloader import *

## data crawling
downloader = YoutubeCommentDownloader()
comments = downloader.get_comments_from_url('https://www.youtube.com/watch?v=LTduwK0-sGI', sort_by=SORT_BY_POPULAR)
for comment in islice(comments, 10):
    print(comment)
    
comments_list = list(comments)

output_file = "ENDEVR.json"
with open(output_file, "w", encoding="utf-8") as f:
    for comment in comments_list:
        json_line = json.dumps(comment, ensure_ascii=False)
        f.write(json_line + "\n")

print(f"Saved {len(comments_list)} comments to '{output_file}'")
# Out:
# ✅ Saved 1569 comments to 'ENDEVR.json' in JSON Lines format

# %%
## preprocessing

import json, re, string
import pandas as pd
import nltk
from nltk.corpus import stopwords

input_data = "ENDEVR.json"
out_berttopic = "ENDEVR_btopic"
out_sent = "ENDEVR_sent"
out_emo = "ENDEVR_emo"
data = []
with open(input_data, "r") as f:
    for line in f:
        line = line.strip()
        if line:
            try:
                data.append(json.loads(line))
            except:
                pass

df = pd.DataFrame(data)
print(f"Loaded {len(df)} comments")
df = df.dropna(subset=["text"])
df["text"] = df["text"].astype(str)

def clean_text(txt):
    txt = txt.lower()
    txt = re.sub(r"http\S+|www\S+", "", txt)
    txt = txt.translate(str.maketrans('', '', string.punctuation))
    txt = re.sub(r"\s+", " ", txt)
    return txt.strip()

df["clean"] = df["text"].apply(clean_text)
print (df["clean"][5])
# Out:
# Loaded 1569 comments
# a couple of years ago i had this dream where i was coming back home at night during winter i recall walking alone down the quiet streets while it was snowing as soon as i arrived home i saw my mother cooking some dinner however i was older which means that she wasnt alive at that time it was then that i realized she was a robot it had some cables at the back of its head overwhelmed with emotion i started to cry as i hugged the robot remembering that my real mother had died it was an eerie dream and im convinced its not too far from reality as robots will never truly replace humans in emotional connections

# %%
## analysis: topic modeling with BERTopic

import matplotlib.pyplot as plt
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

stop_words = stopwords.words("english")

vectorizer = CountVectorizer(stop_words=stop_words)
topic_model = BERTopic(vectorizer_model=vectorizer,
                       language="english",
                       verbose=True,
                       calculate_probabilities=False)
topics, probs = topic_model.fit_transform(df["clean"])

## without stopwords removal
# topic_model = BERTopic(language="english", verbose=True, calculate_probabilities=False)
# topics, probs = topic_model.fit_transform(df["clean"])

df["topic"] = topics
topic_info = topic_model.get_topic_info()

print("\nTop 10 Topics:\n")
print(topic_info.head(10))

df.to_csv(out_berttopic+"_2.csv", index=False)
print("Done! BERTopic results saved")

for i in topic_info.head(11)["Topic"]:
    if i == -1:  # -1 means outliers
        continue
    print(f"\n--- Topic {i}: {topic_model.get_topic(i)} ---")
    sample_comments = df[df["topic"] == i]["text"].head(6).tolist()
    for c in sample_comments:
        print("•", c[:500], "...\n")
# Out:
# 2025-11-11 15:15:19,995 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches: 100%|█████████████████████| 50/50 [00:43<00:00,  1.16it/s]
# 2025-11-11 15:16:05,754 - BERTopic - Embedding - Completed ✓
# 2025-11-11 15:16:05,755 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-11-11 15:16:08,480 - BERTopic - Dimensionality - Completed ✓
# 2025-11-11 15:16:08,484 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-11-11 15:16:08,528 - BERTopic - Cluster - Completed ✓
# 2025-11-11 15:16:08,530 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-11-11 15:16:08,573 - BERTopic - Representation - Completed ✓
# Top 10 Topics:
#
#    Topic  Count                                  Name  \
# 0     -1    510                -1_world_god_life_dont
# 1      0    446                  0_ai_soul_would_body
# 2      1    113            1_forever_live_want_living
# 3      2     66       2_deepak_scooby7877_aq2330_blah
# 4      3     54  3_documentary_movie_terminator_video
# 5      4     50           4_jesus_christ_life_eternal
# 6      5     47     5_immortality_immortal_death_life
# 7      6     43               6_god_choiche_day_every
# 8      7     34                 7_shall_death_seek_96
# 9      8     31         8_chucky_double_antonia_edged
#
#                                       Representation  \
# 0  [world, god, life, dont, im, want, live, like,...
# 1  [ai, soul, would, body, consciousness, human, ...
# 2  [forever, live, want, living, dont, wants, wou...
# 3  [deepak, scooby7877, aq2330, blah, im, 100, ni...
# 4  [documentary, movie, terminator, video, episod...
# 5  [jesus, christ, life, eternal, god, lord, live...
# 6  [immortality, immortal, death, life, would, li...
# 7  [god, choiche, day, every, word, world, want, ...
# 8  [shall, death, seek, 96, flee, days, revelatio...
# 9  [chucky, double, antonia, edged, rip, reals, h...
#
#                                  Representative_Docs
# 0  [live and die naturally don’t need to change a...
# 1  [even if through ai you capture the data of yo...
# 2  [forever is a very long time do you really wan...
# 3  [scooby7877 im not taking suggestions from a n...
# 4  [great documentary, great documentary, i reall...
# 5  [jesus christ is savior all that believe in hi...
# 6  [it doesnt make sense its not you who lives on...
# 7  [why live forever when the world will not be f...
# 8  [revelation 96 and in those days people will s...
# 9  [orbital shield ❤, double edged sword 🗡️🗡️🗡️, ...
# ✅ Done! BERTopic Results saved
#
# --- Topic 0: [('ai', np.float64(0.03995477430868462)), ('soul', np.float64(0.0291716212207813)), ('would', np.float64(0.02320426486973077)), ('body', np.float64(0.022627685770829905)), ('consciousness', np.float64(0.01926517368093117)), ('human', np.float64(0.019158164475931837)), ('mind', np.float64(0.01873903034376986)), ('brain', np.float64(0.018508950342086102)), ('memories', np.float64(0.01725960351964067)), ('copy', np.float64(0.017204631504229736))] ---
# • This film explores these questions with visionaries including Nick Bostrom, author of Superintelligence, Hiroshi Ishiguro, developer of his own uncannily realistic clone Geminoid; Douglas Rushkoff, author of Team Human; Ben Goertzel, founder of Singularity.net who coined the term Artificial General Intelligence; and Deepak Chopra, who is creating his own A.I. mind twin. These visionaries see humanity advancing toward a new age of post-biological life, a world of intelligence without bodies, immo ...
#
# • A couple of years ago, I had this dream where I was coming back home at night during winter. I recall walking alone down the quiet streets while it was snowing. As soon as I arrived home, I saw my mother cooking some dinner. However, I was older, which means that she wasn't alive at that time. It was then that I realized she was a robot; it had some cables at the back of its head. Overwhelmed with emotion, I started to cry as I hugged the robot, remembering that my real mother had died. It was a ...
#
# • People can't even deal with the short life they have, but they want to live forever in some digital world. ...
#
# • The brain is designed to forget. If it took in every piece of information and remembered it we'd go insane. ...
#
# • this is not "living forever." It's an AI powered talking avatar which is not " Living." ...
#
# • This is like ChatGPT, with a persona.  Not the soul of a person, but data reaped from online info. ...
#
#
# --- Topic 1: [('forever', np.float64(0.12738103085623126)), ('live', np.float64(0.1014752783239517)), ('want', np.float64(0.07474503855910143)), ('living', np.float64(0.05964727301486173)), ('dont', np.float64(0.04153037875310921)), ('wants', np.float64(0.03884158689387126)), ('would', np.float64(0.035559556370724374)), ('world', np.float64(0.03334066985238694)), ('life', np.float64(0.03244767442358248)), ('years', np.float64(0.03192507184252095))] ---
# • Who wants to live forever ? Not me in this world. ...
#
# • Living forever sounds like a nightmare actually ...
#
# • Anyone who wants to live forever is just too attached to the world, and that can never be a good thing ...
#
# • I would I'd prefer  to carry  on  that die ...
#
# • Die, death, living forever- how easily these words are thrown around… the only thing anyone should be talking these days is live well. Thrive, be content- what happened to these words? ...
#
# • Cool, I'll kill you today then. Not what you want? Ok, what day will you tell me you want to die? This world is all we have, and you can never compare endless nonexistence to existing. It's not like comparing apples and oranges, it's comparing an apple to no apple. It's not like you get a nice break from this terrible ol' world when you die, you cease to BE. Forever. You don't wake up after a nice long nap. You can't enjoy the peace of the grave. If you truly understood what death was, you would ...
#
#
# --- Topic 2: [('deepak', np.float64(0.06532527616634622)), ('scooby7877', np.float64(0.0596911000577466)), ('aq2330', np.float64(0.04708662449177643)), ('blah', np.float64(0.04708662449177643)), ('im', np.float64(0.04631374132984413)), ('100', np.float64(0.0455565803194448)), ('nihilist', np.float64(0.033571559696435244)), ('comments', np.float64(0.033571559696435244)), ('hobojungle1', np.float64(0.033571559696435244)), ('indoctrination', np.float64(0.033571559696435244))] ---
# •  @MamaMia84oo7  I wouldn't need a dollar.....and I'd be happy living forever ...
#
# •  @jamesfreeman8894  I feel the same way. ...
#
# • Gemini and electrum are the right one ...
#
# • ​ @lawerancelanham explain with examples or you sound just as hateful ...
#
# • ​ @daveycrocker4466 exactly ...
#
# • ​ @MamaMia84oo7 only.if your loved ones are around. ...
#
#
# --- Topic 3: [('documentary', np.float64(0.10603106691131053)), ('movie', np.float64(0.05951229330462683)), ('terminator', np.float64(0.054220277395991244)), ('video', np.float64(0.04858779132612814)), ('episode', np.float64(0.04677984784950992)), ('great', np.float64(0.04542594135819774)), ('black', np.float64(0.04383525570471087)), ('mirror', np.float64(0.04383525570471087)), ('thought', np.float64(0.04114153001744456)), ('2023', np.float64(0.037423878279607935))] ---
# • This feels very much like that episode from the black mirror ...
#
# • IDK why, but I was brought nearly to tears towards the ending of the video.  I guess it's because of all the advancements in tech, despite all that, "what will be, will be"...and that what's truly important is not what the future holds, but the moments we have with those closest to us in the present time. ...
#
# • I viewed this from a purely journalistic perspective; an amazing story which requires deeper investigation. Ann achieved that goal beautifully. Well researched, well written, and the production value was excellent. In the end, it did what any great documentary should do. It left we the viewers to decide for ourselves. Well done Ann. ...
#
# • The ending was great! 🥲 ...
#
# • I thought the same thing just from the title without even had watched it yet ...
#
# • That’s exactly what this is.. that whole series is showing us what they have coming to us before it comes… ...
#
#
# --- Topic 4: [('jesus', np.float64(0.1988061520490133)), ('christ', np.float64(0.10542160957312427)), ('life', np.float64(0.10411471184610377)), ('eternal', np.float64(0.09498404271057855)), ('god', np.float64(0.04358792382245285)), ('lord', np.float64(0.041902610593716735)), ('live', np.float64(0.040846290152838895)), ('john', np.float64(0.04052788872527499)), ('forever', np.float64(0.037845088877575955)), ('nazareth', np.float64(0.037032438330140444))] ---
# • I TOTALLY AGREE!!! The human heart is dark… 🖤…..ONLY Jesus can change those desires AND I WILL live forever in Eternity because I’m forgiven🌺🥺 ...
#
# • There is no option . Death is mandatory. The Bible says that the wages of sin is death but the gift of God is eternal life through Jesus Christ our Lord ...
#
# • ​ @Imperfectionist505 You can't pick and choose from the Bible; you have to read and "rightly divide."  Read the context.
# THIS is NOT how we live forever!  Only Jesus can renew our bodies incorruptible; NOT man! ...
#
# • I want eternal holy life..not artificial life❤ ...
#
# • Eternal life is in Jesus Christ. ...
#
# • We can to live forever in Hause od our LORD , its possible..❤...And it might to be very beautiful in this place ...  But this all , what shoud to will not  be from our LORD its from the  OPPOSIDE ... ...
#
#
# --- Topic 5: [('immortality', np.float64(0.08510614386706612)), ('immortal', np.float64(0.06870652592553547)), ('death', np.float64(0.035548266233215504)), ('life', np.float64(0.03249993913406341)), ('would', np.float64(0.03149787997350581)), ('like', np.float64(0.027624997012513933)), ('young', np.float64(0.026024888545196717)), ('forever', np.float64(0.02570418117054152)), ('aging', np.float64(0.02539776283995757)), ('people', np.float64(0.024010209000444423))] ---
# • Living experience goes to Hollywood?why a theoretical assumption as immortality should confirm long terms of measure enchained in a material body..which anyway Is confined to lass of time...
# More than that.... ...
#
# • I would. I would have a lot of time to change it, keep a personal eye on what is actually happening over time, too. Plus, this video is about making death voluntary. The CHOICE is interesting to me. ...
#
# • Why not change it using your immortal life ...
#
# • @TechnoMinded-qp5in I am 29 and people think I'm around 19 to 21. Maybe we are immortals? ...
#
# • @TechnoMinded-qp5in for me it's less of a desire to live forever and more about not getting old. I fear that more than death. ...
#
# • I see it as more about options. If you don't need it don't use it. Some may need it in the beginning and slowly move away as they start their new lifestyle. ...
#
#
# --- Topic 6: [('god', np.float64(0.15079260257916333)), ('choiche', np.float64(0.03674039765424485)), ('day', np.float64(0.033423126668572826)), ('every', np.float64(0.03218059166869436)), ('word', np.float64(0.02996113387084482)), ('world', np.float64(0.02937285459722684)), ('want', np.float64(0.028909651277404518)), ('heavenly', np.float64(0.02887460774619679)), ('live', np.float64(0.028838348891850843)), ('playing', np.float64(0.028386053302196693))] ---
# • But is it in god ...
#
# • Its a sad world when it has no faith in the Creator and instead actually believes they themselves are god. This is the most hopeless video I have seen in a while. If every human beings were actually able to live forever in the state they are in without weeding out the bad from the good they would destroy the entire universe and then there would be no life at all anywhere. Thank God for God. ...
#
# • Exactly...they are trien to find a way to beat God and its not going to happen they will all be destroyed ...
#
# • No one can live forever in this fallen world and God intended in a certain way that we all die because of sin, rebellion and corruption. God has prepared a beautiful place of an eternity to those who believe in him. This world is not good to live forever due to the sinful and corrupt nature of things. ...
#
# • The people who sin …. Afraid of judgement day. They won’t have to face god. They want sex drugs & rock n roll. They want free will. They want to live forever. They want to be GOD. ...
#
# • ​ @thecryptoendgame
#  Every one has to face God ... the ppl who want Rock n Role n wanna play God were created by Him!  Just bad kids being rebellious ...
#
#
# --- Topic 7: [('shall', np.float64(0.1275572183889254)), ('death', np.float64(0.1245861615633191)), ('seek', np.float64(0.09788639462752947)), ('96', np.float64(0.09683819945467155)), ('flee', np.float64(0.08962879266458923)), ('days', np.float64(0.08270478028142933)), ('revelation', np.float64(0.08222700298727321)), ('die', np.float64(0.08141246612905917)), ('men', np.float64(0.07170303413167138)), ('find', np.float64(0.07150684852727446))] ---
# • “The righteous will possess the earth, and they will live forever on it.”
# Psalm 37:29
#
# “The earth remains forever.”
# Ecclesiastes 1:4
#
# “He will wipe out every tear from their eyes, and death will be no more, neither will mourning nor outcry nor pain be anymore. The former things have passed away.”
# Revelation 21:4 ...
#
# • Rev. 9.6  And in those days shall men seek death and shall not find it.and shall desire to die , and death shall flee from them. ...
#
# • ​ @carriearmstrong7939  pioners on this aberration  will not be here in 100 years, will die and face the Creator of the Universe,., PEOPLE ARE DESTINED TO DIE ONCE, AND AFTER THAT TO FACE JUDGEMENT! ( Hebrews 9:27) ...
#
# • ​ @icanseeclearlynow4355 well I believe they're talking about spiritual death there with the the first death ...
#
# •  @Chat_Liveman  do you think rapture is gonna be some catastrophy like a boom or something like all at once? Why is no one fighting the dark side rite now and just letting them run a muck doing what they are doing? ...
#
# •  @cezz1105  Revelation 9:6. ESV And in those days people will seek death and will not find it. They will long to die, but death will flee from them ...
#
#
# --- Topic 8: [('chucky', np.float64(0.3641938868340743)), ('double', np.float64(0.3641938868340743)), ('antonia', np.float64(0.3641938868340743)), ('edged', np.float64(0.3641938868340743)), ('rip', np.float64(0.3641938868340743)), ('reals', np.float64(0.3641938868340743)), ('heron1835', np.float64(0.3641938868340743)), ('orbital', np.float64(0.3641938868340743)), ('foolishness', np.float64(0.3641938868340743)), ('galicia', np.float64(0.3641938868340743))] ---
# • For reals 😊 ...
#
# • Double edged sword 🗡️🗡️🗡️ ...
#
# • ​ @benyahudadavidl Facts💯 ...
#
# • Ĝ😂😅😮e😢fu ...
#
# • 🧠👅 ...
#
# • 🎉😮🎉😮🎉 ...
#
#
# --- Topic 9: [('agree', np.float64(0.4002104489715995)), ('point', np.float64(0.3370055811684004)), ('agreed', np.float64(0.2592288154002111)), ('lmao', np.float64(0.2503830696010002)), ('good', np.float64(0.21442622573309195)), ('hmmm', np.float64(0.16877277682554662)), ('oo', np.float64(0.16877277682554662)), ('pic', np.float64(0.16877277682554662)), ('cunningham', np.float64(0.16877277682554662)), ('zzzzz', np.float64(0.16877277682554662))] ---
# • Lmao ...
#
# • @Brenda Cunningham
# Can't agree more ...
#
# • Right I agree ...
#
# • Yes I would ...
#
# • Yea ...
#
# • I would ...

# %%
# !pip install transformers torch --quiet
from transformers import pipeline

model_emo_rlarge = "cardiffnlp/twitter-roberta-large-emotion-latest"
model_emo_rbase = "cardiffnlp/twitter-roberta-base-emotion-latest"
model_sent_rbase = "cardiffnlp/twitter-roberta-base-sentiment-latest"
model_emo_dbertbase ="bhadresh-savani/distilbert-base-uncased-emotion"

# Load sentiment analysis pipeline
sentiment_model = pipeline(
    "sentiment-analysis",
    model=model_emo_rlarge
)
# Out:
# Device set to use cpu

# %%
## analysis: sentiment/emotion analysis via Transformer-based LLM

## emotion labels
id2label = { 
    "0": "anger", "1": "anticipation", "2": "disgust", "3": "fear",
    "4": "joy", "5": "love", "6": "optimism", "7": "pessimism",
    "8": "sadness", "9": "surprise", "10": "trust" 
}

## sentiment labels
id2label_sent = { 
    "0": "Negative", "1": "Neutral", "2": "Positive"
}

## using emotion model
def get_emotion_hf(text):
    try:
        result = sentiment_model(text[:256])[0]  # truncate to 256 tokens
        label_id = result["label"].replace("LABEL_", "")  # extract numeric ID
        label_name = id2label.get(label_id, result["label"])  # map to emotion
        return label_name, float(result["score"])
    except:
        return None, None

## using sentiment model
def get_sentiment_hf(text):
    try:
        result = sentiment_model(text[:256])[0]   # truncate to 512 tokens
        label_id = result["label"].replace("LABEL_", "")  # extract numeric ID
        label_name = id2label_sent.get(label_id, result["label"])  # map to emotion
        return label_name, float(result["score"])
        # return result["label"], float(result["score"])
    except:
        return None, None

## sentiment analysis
df[["hf_label", "hf_score"]] = df["clean"].apply(lambda x: pd.Series(get_sentiment_hf(x)))
print(df["hf_label"].value_counts())
df.to_csv(out_sent+".csv", index=False)
print(f"✅ Predictions saved as {out_sent}.csv")

## emotion analysis
df[["hf_label", "hf_score"]] = df["clean"].apply(lambda x: pd.Series(get_emotion_hf(x)))
print(df["hf_label"].value_counts())
df.to_csv(out_emo+".csv", index=False)
print(f"✅ Predictions saved as {out_sent}.csv")
# Out:
# hf_label
# optimism        369
# anticipation    287
# sadness         254
# joy             233
# disgust         206
# anger            99
# fear             75
# surprise         23
# love             14
# pessimism         8
# Name: count, dtype: int64
# ✅ Predictions saved as ENDEVR_sent.csv
